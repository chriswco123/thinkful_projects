# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in /opt/anaconda3/lib/python3.8/site-packages (4.13.0)
# Requirement already satisfied: retrying>=1.3.3 in /opt/anaconda3/lib/python3.8/site-packages (from plotly) (1.3.3)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.8/site-packages (from plotly) (1.15.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as px

# %%
df = pd.read_csv('./College.csv')
df
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
#      Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  \
# 0           52         2885          537      7440        3300    450
# 1           29         2683         1227     12280        6450    750
# 2           50         1036           99     11250        3750    400
# 3           89          510           63     12960        5450    450
# 4           44          249          869      7560        4120    800
# ..         ...          ...          ...       ...         ...    ...
# 772         26         3089         2029      6797        3900    500
# 773         47         2849         1107     11520        4960    600
# 774         61         2793          166      6900        4200    617
# 775         99         5217           83     19840        6510    630
# 776         63         2988         1726      4990        3560    500
#
#      Personal  PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0        2200   70        78       18.1           12    7041         60
# 1        1500   29        30       12.2           16   10527         56
# 2        1165   53        66       12.9           30    8735         54
# 3         875   92        97        7.7           37   19016         59
# 4        1500   76        72       11.9            2   10922         15
# ..        ...  ...       ...        ...          ...     ...        ...
# 772      1200   60        60       21.0           14    4469         40
# 773      1250   73        75       13.3           31    9189         83
# 774       781   67        75       14.4           20    8323         49
# 775      2115   96        96        5.8           49   40386         99
# 776      1250   75        75       18.1           28    4509         99
#
# [777 rows x 19 columns]

# %%
df.isnull().sum()
#no missing values
# Out:
# Unnamed: 0     0
# Private        0
# Apps           0
# Accept         0
# Enroll         0
# Top10perc      0
# Top25perc      0
# F.Undergrad    0
# P.Undergrad    0
# Outstate       0
# Room.Board     0
# Books          0
# Personal       0
# PhD            0
# Terminal       0
# S.F.Ratio      0
# perc.alumni    0
# Expend         0
# Grad.Rate      0
# dtype: int64

# %%
df.dtypes
#checking for data types
# Out:
# Unnamed: 0      object
# Private         object
# Apps             int64
# Accept           int64
# Enroll           int64
# Top10perc        int64
# Top25perc        int64
# F.Undergrad      int64
# P.Undergrad      int64
# Outstate         int64
# Room.Board       int64
# Books            int64
# Personal         int64
# PhD              int64
# Terminal         int64
# S.F.Ratio      float64
# perc.alumni      int64
# Expend           int64
# Grad.Rate        int64
# dtype: object

# %%
#checking 'Private' column
df['Private'].value_counts()
# Out:
# Yes    565
# No     212
# Name: Private, dtype: int64

# %%
#converting everything to non-string
df['Private'] = df['Private'].map(lambda x: 1 if x =='Yes' else 0)
df['Private'].value_counts()
# Out:
# 1    565
# 0    212
# Name: Private, dtype: int64

# %%
#confirming
df.dtypes
# Out:
# Unnamed: 0      object
# Private          int64
# Apps             int64
# Accept           int64
# Enroll           int64
# Top10perc        int64
# Top25perc        int64
# F.Undergrad      int64
# P.Undergrad      int64
# Outstate         int64
# Room.Board       int64
# Books            int64
# Personal         int64
# PhD              int64
# Terminal         int64
# S.F.Ratio      float64
# perc.alumni      int64
# Expend           int64
# Grad.Rate        int64
# dtype: object

# %%
df.describe()
#checking columns, note that max Grad.Rate is 118
# Out:
#           Private          Apps        Accept       Enroll   Top10perc  \
# count  777.000000    777.000000    777.000000   777.000000  777.000000
# mean     0.727156   3001.638353   2018.804376   779.972973   27.558559
# std      0.445708   3870.201484   2451.113971   929.176190   17.640364
# min      0.000000     81.000000     72.000000    35.000000    1.000000
# 25%      0.000000    776.000000    604.000000   242.000000   15.000000
# 50%      1.000000   1558.000000   1110.000000   434.000000   23.000000
# 75%      1.000000   3624.000000   2424.000000   902.000000   35.000000
# max      1.000000  48094.000000  26330.000000  6392.000000   96.000000
#
#         Top25perc   F.Undergrad   P.Undergrad      Outstate   Room.Board  \
# count  777.000000    777.000000    777.000000    777.000000   777.000000
# mean    55.796654   3699.907336    855.298584  10440.669241  4357.526384
# std     19.804778   4850.420531   1522.431887   4023.016484  1096.696416
# min      9.000000    139.000000      1.000000   2340.000000  1780.000000
# 25%     41.000000    992.000000     95.000000   7320.000000  3597.000000
# 50%     54.000000   1707.000000    353.000000   9990.000000  4200.000000
# 75%     69.000000   4005.000000    967.000000  12925.000000  5050.000000
# max    100.000000  31643.000000  21836.000000  21700.000000  8124.000000
#
#              Books     Personal         PhD    Terminal   S.F.Ratio  \
# count   777.000000   777.000000  777.000000  777.000000  777.000000
# mean    549.380952  1340.642214   72.660232   79.702703   14.089704
# std     165.105360   677.071454   16.328155   14.722359    3.958349
# min      96.000000   250.000000    8.000000   24.000000    2.500000
# 25%     470.000000   850.000000   62.000000   71.000000   11.500000
# 50%     500.000000  1200.000000   75.000000   82.000000   13.600000
# 75%     600.000000  1700.000000   85.000000   92.000000   16.500000
# max    2340.000000  6800.000000  103.000000  100.000000   39.800000
#
#        perc.alumni        Expend  Grad.Rate
# count   777.000000    777.000000  777.00000
# mean     22.743887   9660.171171   65.46332
# std      12.391801   5221.768440   17.17771
# min       0.000000   3186.000000   10.00000
# 25%      13.000000   6751.000000   53.00000
# 50%      21.000000   8377.000000   65.00000
# 75%      31.000000  10830.000000   78.00000
# max      64.000000  56233.000000  118.00000

# %%
#check for over 100 grad. rate
df[df['Grad.Rate'] > 100]
# Out:
#            Unnamed: 0  Private  Apps  Accept  Enroll  Top10perc  Top25perc  \
# 95  Cazenovia College        1  3847    3433     527          9         35
#
#     F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  \
# 95         1010           12      9384        4840    600       500   22
#
#     Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 95        47       14.3           20    7697        118

# %%
#might be a error in the df, changing it to 100.
df[df['Grad.Rate'] > 100] = 100
df[df['Grad.Rate'] > 100]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Private, Apps, Accept, Enroll, Top10perc, Top25perc, F.Undergrad, P.Undergrad, Outstate, Room.Board, Books, Personal, PhD, Terminal, S.F.Ratio, perc.alumni, Expend, Grad.Rate]
# Index: []

# %%
df['cost'] = df['Outstate'] + df['Room.Board'] + df['Books'] + df['Personal']
df['degree'] = (df['PhD'] + df['Terminal']) / 2
df['accept.rate'] = df['Accept'] / df['Apps']
df['under'] = df['F.Undergrad'] + df['P.Undergrad']
df
# Out:
#                          Unnamed: 0  Private   Apps  Accept  Enroll  \
# 0      Abilene Christian University        1   1660    1232     721
# 1                Adelphi University        1   2186    1924     512
# 2                    Adrian College        1   1428    1097     336
# 3               Agnes Scott College        1    417     349     137
# 4         Alaska Pacific University        1    193     146      55
# ..                              ...      ...    ...     ...     ...
# 772         Worcester State College        0   2197    1515     543
# 773               Xavier University        1   1959    1805     695
# 774  Xavier University of Louisiana        1   2097    1915     695
# 775                 Yale University        1  10705    2453    1317
# 776    York College of Pennsylvania        1   2989    1855     691
#
#      Top10perc  Top25perc  F.Undergrad  P.Undergrad  Outstate  ...  PhD  \
# 0           23         52         2885          537      7440  ...   70
# 1           16         29         2683         1227     12280  ...   29
# 2           22         50         1036           99     11250  ...   53
# 3           60         89          510           63     12960  ...   92
# 4           16         44          249          869      7560  ...   76
# ..         ...        ...          ...          ...       ...  ...  ...
# 772          4         26         3089         2029      6797  ...   60
# 773         24         47         2849         1107     11520  ...   73
# 774         34         61         2793          166      6900  ...   67
# 775         95         99         5217           83     19840  ...   96
# 776         28         63         2988         1726      4990  ...   75
#
#      Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate   cost  degree  \
# 0          78       18.1           12    7041         60  13390    74.0
# 1          30       12.2           16   10527         56  20980    29.5
# 2          66       12.9           30    8735         54  16565    59.5
# 3          97        7.7           37   19016         59  19735    94.5
# 4          72       11.9            2   10922         15  13980    74.0
# ..        ...        ...          ...     ...        ...    ...     ...
# 772        60       21.0           14    4469         40  12397    60.0
# 773        75       13.3           31    9189         83  18330    74.0
# 774        75       14.4           20    8323         49  12498    71.0
# 775        96        5.8           49   40386         99  29095    96.0
# 776        75       18.1           28    4509         99  10300    75.0
#
#      accept.rate  under
# 0       0.742169   3422
# 1       0.880146   3910
# 2       0.768207   1135
# 3       0.836930    573
# 4       0.756477   1118
# ..           ...    ...
# 772     0.689577   5118
# 773     0.921388   3956
# 774     0.913209   2959
# 775     0.229145   5300
# 776     0.620609   4714
#
# [777 rows x 23 columns]

# %%
X = df[['cost','degree','accept.rate','under','Top25perc','perc.alumni','Expend','Grad.Rate']]
X
# Out:
#       cost  degree  accept.rate  under  Top25perc  perc.alumni  Expend  \
# 0    13390    74.0     0.742169   3422         52           12    7041
# 1    20980    29.5     0.880146   3910         29           16   10527
# 2    16565    59.5     0.768207   1135         50           30    8735
# 3    19735    94.5     0.836930    573         89           37   19016
# 4    13980    74.0     0.756477   1118         44            2   10922
# ..     ...     ...          ...    ...        ...          ...     ...
# 772  12397    60.0     0.689577   5118         26           14    4469
# 773  18330    74.0     0.921388   3956         47           31    9189
# 774  12498    71.0     0.913209   2959         61           20    8323
# 775  29095    96.0     0.229145   5300         99           49   40386
# 776  10300    75.0     0.620609   4714         63           28    4509
#
#      Grad.Rate
# 0           60
# 1           56
# 2           54
# 3           59
# 4           15
# ..         ...
# 772         40
# 773         83
# 774         49
# 775         99
# 776         99
#
# [777 rows x 8 columns]

# %%
#clustering
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
X_scale = pd.DataFrame(scale.fit_transform(X), columns=X.columns)
X_scale
# Out:
#          cost    degree  accept.rate     under  Top25perc  perc.alumni  \
# 0   -0.696412 -0.152359    -0.033272 -0.193496  -0.195568    -0.854797
# 1    0.915588 -3.144704     0.904097 -0.110092  -1.354768    -0.539573
# 2   -0.022090 -1.127392     0.143625 -0.584368  -0.296368     0.563712
# 3    0.651169  1.226138     0.610504 -0.680419   1.669233     1.115354
# 4   -0.571105 -0.152359     0.063931 -0.587273  -0.598768    -1.642858
# ..        ...       ...          ...       ...        ...          ...
# 772 -0.907310 -1.093771    -0.390562  0.096368  -1.505968    -0.697185
# 773  0.352769 -0.152359     1.184280 -0.102230  -0.447568     0.642518
# 774 -0.885859 -0.354090     1.128715 -0.272627   0.258033    -0.224349
# 775  2.639091  1.327003    -3.518562  0.127474   2.173234     2.061027
# 776 -1.352681 -0.085115    -0.859104  0.027320   0.358833     0.406100
#
#        Expend  Grad.Rate
# 0   -0.499006  -0.317993
# 1    0.167637  -0.551805
# 2   -0.175055  -0.668710
# 3    1.791027  -0.376446
# 4    0.243175  -2.948375
# ..        ...        ...
# 772 -0.990861  -1.487051
# 773 -0.088234   1.026424
# 774 -0.253843  -0.960975
# 775  5.877708   1.961671
# 776 -0.983212   1.961671
#
# [777 rows x 8 columns]

# %%
from sklearn.cluster import KMeans
inertia = []
K = range(2,30)
for k in K:
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(X_scale)
    inertia.append(kmeans.inertia_)
plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('Inertia')
plt.title('Elbow Method vs. Optimal K')
plt.show()
#elbow at 4 clusters

# %%
from sklearn.metrics import silhouette_score

sil_score = []
K = range(2,30)
for k in K:
    kmeans = KMeans(n_clusters=k)
    sil_score.append(silhouette_score(X_scale, kmeans.fit_predict(X_scale)))
plt.figure(figsize=(16,8))
plt.plot(K, sil_score, 'bx-')
plt.xlabel('k')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Method vs. Optimal K')
plt.show()

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(X_scale)
kmeans.cluster_centers_
# Out:
# array([[ 1.07015017,  0.78370777, -0.3808428 , -0.29192447,  0.85376517,
#          0.83837909,  0.85876041,  0.83003227],
#        [-0.61690835,  0.61664669, -0.40170138,  1.70240387,  0.16140095,
#         -0.67526176, -0.26553036, -0.52191892],
#        [-0.42893106, -0.66498807,  0.35666102, -0.38678955, -0.55683013,
#         -0.27299454, -0.4195758 , -0.31842592]])

# %%
#showing dimensionality-reduced clusters with PCA
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pc = pca.fit_transform(X_scale)
df2 = pd.DataFrame(pc)
km=KMeans(n_clusters=20)
X_clustered=km.fit_predict(df2)
df2['cluster'] = X_clustered

center=km.cluster_centers_

plt.figure(figsize=(14,10))
plt.scatter(pc[:,0],pc[:,1],c=df2['cluster'],alpha=0.5)
plt.scatter(center[:, 0], center[:, 1], c='black', s=100, alpha=0.9)
plt.show()

# %%
#cluster centers
km=KMeans(n_clusters=20)
X_clustered=km.fit_predict(X_scale)
centers = pd.DataFrame(km.cluster_centers_,columns=X.columns)
center_inverse = pd.DataFrame(scale.inverse_transform(centers), columns=X.columns)
center_inverse.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_06eb157c_35a0_11eb_8a3c_acde48001122row0_col0 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row0_col1 {
#             background-color:  #04598c;
#             color:  #f1f1f1;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row0_col2 {
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row0_col4 {
#             background-color:  #197db7;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row0_col5 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row0_col6 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row0_col7 {
#             background-color:  #7eadd1;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row1_col0 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row1_col1 {
#             background-color:  #3b92c1;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row1_col2 {
#             background-color:  #04588a;
#             color:  #f1f1f1;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row1_col3 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row1_col4 {
#             background-color:  #3991c1;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row1_col5 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row1_col6 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row1_col7 {
#             background-color:  #99b8d8;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row2_col0 {
#             background-color:  #045280;
#             color:  #f1f1f1;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row2_col1 {
#             background-color:  #03466e;
#             color:  #f1f1f1;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row2_col2 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row2_col3 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row2_col4 {
#             background-color:  #045382;
#             color:  #f1f1f1;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row2_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row2_col6 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row2_col7 {
#             background-color:  #034a74;
#             color:  #f1f1f1;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row3_col1 {
#             background-color:  #63a2cb;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row3_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row3_col3 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row3_col4 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row3_col5 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row3_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row3_col7 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row4_col0 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row4_col1 {
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row4_col2 {
#             background-color:  #acc0dd;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row4_col3 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row4_col4 {
#             background-color:  #a4bcda;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row4_col5 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row4_col6 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row4_col7 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row5_col0 {
#             background-color:  #045687;
#             color:  #f1f1f1;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row5_col1 {
#             background-color:  #034d79;
#             color:  #f1f1f1;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row5_col2 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row5_col3 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row5_col4 {
#             background-color:  #1b7eb7;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row5_col5 {
#             background-color:  #358fc0;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row5_col6 {
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row5_col7 {
#             background-color:  #056ead;
#             color:  #f1f1f1;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row6_col0 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row6_col1 {
#             background-color:  #c1cae2;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row6_col2 {
#             background-color:  #04598c;
#             color:  #f1f1f1;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row6_col3 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row6_col4 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row6_col5 {
#             background-color:  #75a9cf;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row6_col6 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row6_col7 {
#             background-color:  #abbfdc;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row7_col0 {
#             background-color:  #dfddec;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row7_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row7_col2 {
#             background-color:  #03446a;
#             color:  #f1f1f1;
#         }    #T_06eb157c_35a0_11eb_8a3c_acde48001122row7_col3 {
#             background-color:  #fbf4f9;
#             color:  #000000;

# %%
from sklearn.cluster import DBSCAN

scale = StandardScaler()
X_scale = pd.DataFrame(scale.fit_transform(X), columns=X.columns)


pca = PCA(n_components=2).fit_transform(X_scale)
df3 = pd.DataFrame(pca)
dbscan = DBSCAN(eps=0.15, min_samples=4)
X_clusters = dbscan.fit_predict(df3)
df3['cluster'] = X_clusters

plt.figure(figsize=(14,10))
plt.scatter(df3[0],df3[1],c=df3['cluster'],alpha=0.5)
plt.show()
#Tried several parameters and none of them seem to work properly, discard dbscan.

# %%
df3['cluster'].value_counts()
# Out:
# -1     331
#  4     118
#  1      83
#  3      41
#  19     18
#  15     15
#  18     13
#  20     11
#  24     10
#  8      10
#  17      9
#  29      9
#  5       8
#  0       7
#  7       6
#  33      5
#  21      5
#  2       5
#  16      5
#  14      5
#  13      5
#  10      4
#  32      4
#  6       4
#  30      4
#  25      4
#  11      4
#  23      4
#  34      4
#  28      4
#  27      4
#  26      4
#  22      4
#  12      4
#  9       3
#  31      3
# Name: cluster, dtype: int64

# %%
from sklearn.cluster import AgglomerativeClustering

scale = StandardScaler()
X_scale3 = pd.DataFrame(scale.fit_transform(X), columns=X.columns)


pca = PCA(n_components=2).fit_transform(X_scale3)
df4 = pd.DataFrame(pca)
agg = AgglomerativeClustering(linkage='complete', affinity='cosine', n_clusters=20)
X_clusters = agg.fit_predict(df4)

plt.figure(figsize=(14,10))
plt.scatter(pc[:,0],pc[:,1],c=X_clusters,alpha=0.5)
plt.show()

# %%
X_scale3['cluster'] = X_clusters
pd.DataFrame(scale.inverse_transform(X_scale3.groupby('cluster').mean()),columns=X.columns).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_073ae3f4_35a0_11eb_8a3c_acde48001122row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row0_col3 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row0_col5 {
#             background-color:  #046097;
#             color:  #f1f1f1;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row0_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row0_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row1_col0 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row1_col1 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row1_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row1_col3 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row1_col5 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row1_col6 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row1_col7 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row2_col0 {
#             background-color:  #a2bcda;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row2_col1 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row2_col2 {
#             background-color:  #023a5b;
#             color:  #f1f1f1;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row2_col3 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row2_col4 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row2_col5 {
#             background-color:  #3d93c2;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row2_col6 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row2_col7 {
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row3_col0 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row3_col1 {
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row3_col2 {
#             background-color:  #034b76;
#             color:  #f1f1f1;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row3_col3 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row3_col4 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row3_col5 {
#             background-color:  #0c74b2;
#             color:  #f1f1f1;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row3_col6 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row3_col7 {
#             background-color:  #2484ba;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row4_col0 {
#             background-color:  #69a5cc;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row4_col1 {
#             background-color:  #7dacd1;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row4_col2 {
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row4_col3 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row4_col4 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row4_col5 {
#             background-color:  #045382;
#             color:  #f1f1f1;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row4_col6 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row4_col7 {
#             background-color:  #0570b0;
#             color:  #f1f1f1;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row5_col0 {
#             background-color:  #046299;
#             color:  #f1f1f1;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row5_col1 {
#             background-color:  #034e7b;
#             color:  #f1f1f1;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row5_col2 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row5_col3 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row5_col4 {
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row5_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row5_col6 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row5_col7 {
#             background-color:  #045f95;
#             color:  #f1f1f1;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row6_col0 {
#             background-color:  #4a98c5;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row6_col1 {
#             background-color:  #2182b9;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row6_col2 {
#             background-color:  #03517e;
#             color:  #f1f1f1;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row6_col3 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row6_col4 {
#             background-color:  #75a9cf;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row6_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row6_col6 {
#             background-color:  #c6cce3;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row6_col7 {
#             background-color:  #0c74b2;
#             color:  #f1f1f1;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row7_col0 {
#             background-color:  #60a1ca;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row7_col1 {
#             background-color:  #0566a0;
#             color:  #f1f1f1;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row7_col2 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_073ae3f4_35a0_11eb_8a3c_acde48001122row7_col3 {
#             background-color:  #8cb3d5;
#             color:  #000000;

# %%
from sklearn.mixture import GaussianMixture

scale = StandardScaler()
X_scale4 = pd.DataFrame(scale.fit_transform(X), columns=X.columns)


pca = PCA(n_components=2).fit_transform(X_scale4)
df5 = pd.DataFrame(pca)
gmm = GaussianMixture(n_components=20, random_state=123)
gmm_clusters = gmm.fit_predict(df5)


plt.figure(figsize=(14,10))
plt.scatter(pc[:,0],pc[:,1],c=gmm_clusters,alpha=0.5)
plt.show()

# %%
X_scale4['cluster'] = gmm_clusters
pd.DataFrame(scale.inverse_transform(X_scale4.groupby('cluster').mean()),columns=X.columns).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_0780a25e_35a0_11eb_8a3c_acde48001122row0_col0 {
#             background-color:  #62a2cb;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row0_col1 {
#             background-color:  #056caa;
#             color:  #f1f1f1;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row0_col2 {
#             background-color:  #2d8abd;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row0_col3 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row0_col4 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row0_col5 {
#             background-color:  #c1cae2;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row0_col6 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row0_col7 {
#             background-color:  #529bc7;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row1_col0 {
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row1_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row1_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row1_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row1_col4 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row1_col5 {
#             background-color:  #acc0dd;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row1_col6 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row1_col7 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row2_col0 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row2_col1 {
#             background-color:  #2081b9;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row2_col2 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row2_col3 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row2_col4 {
#             background-color:  #b9c6e0;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row2_col5 {
#             background-color:  #e0deed;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row2_col6 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row2_col7 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row3_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row3_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row3_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row3_col3 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row3_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row3_col5 {
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row3_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row3_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row4_col0 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row4_col1 {
#             background-color:  #045382;
#             color:  #f1f1f1;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row4_col2 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row4_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row4_col4 {
#             background-color:  #0569a5;
#             color:  #f1f1f1;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row4_col5 {
#             background-color:  #b9c6e0;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row4_col6 {
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row4_col7 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row5_col0 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row5_col1 {
#             background-color:  #0568a3;
#             color:  #f1f1f1;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row5_col2 {
#             background-color:  #04649e;
#             color:  #f1f1f1;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row5_col3 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row5_col4 {
#             background-color:  #60a1ca;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row5_col5 {
#             background-color:  #1b7eb7;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row5_col6 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row5_col7 {
#             background-color:  #197db7;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row6_col1 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row6_col2 {
#             background-color:  #02395a;
#             color:  #f1f1f1;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row6_col3 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row6_col5 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row6_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row6_col7 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row7_col0 {
#             background-color:  #358fc0;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row7_col1 {
#             background-color:  #04588a;
#             color:  #f1f1f1;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row7_col2 {
#             background-color:  #9ebad9;
#             color:  #000000;
#         }    #T_0780a25e_35a0_11eb_8a3c_acde48001122row7_col3 {
#             background-color:  #7bacd1;
#             color:  #000000;

# %%
X_scale4['name'] = df['Unnamed: 0']
X_scale4[X_scale4['cluster'] == 3]
# Out:
#          cost    degree  accept.rate     under  Top25perc  perc.alumni  \
# 16   2.261683  1.293381    -3.508744 -0.505236   2.022034     3.164312
# 60   2.254674  1.226138    -3.012504 -0.522327   2.223634     2.297445
# 70   2.252338  1.562356    -3.326953  0.245744   1.971634     1.272967
# 144  2.011069  1.427869    -3.134540 -0.191958   2.022034    -0.145543
# 158  2.250427  1.394247    -3.276999 -0.103255   2.173234     2.061027
# 174  2.051210  1.293381    -3.157268  0.288300   2.122834     1.666997
# 191  1.784242  1.427869    -1.746364  0.201991   2.072434     0.406100
# 221  2.364265  1.024407    -3.314386  0.296162   1.870834     0.327294
# 250  2.261046  1.394247    -4.014474  0.449127   2.223634     2.297445
# 251  1.879815  1.595978    -2.253245 -0.665721   2.223634     1.824609
# 284  2.211135  1.360625    -2.312622  0.099274   1.921234     1.194160
# 354  2.491483  1.528734    -2.807568 -0.007716   2.173234     0.957742
# 424  1.613909  1.461491    -2.200616  0.502622   2.122834     0.169682
# 459  2.419272  1.158894    -4.025767  0.022535   2.122834     2.455058
# 609  2.207737  1.528734    -1.865761 -0.200845   1.921234     1.036548
# 663  2.052696  1.293381    -2.207429  0.885632   2.223634     1.194160
# 720  0.698956  1.327003    -2.204709 -0.150939   1.618833     1.115354
# 728  2.067776  1.226138    -0.407444  0.273260   1.870834     0.642518
# 733  1.884063  1.327003    -2.144291 -0.376541   2.022034     2.218639
# 763  2.219418  1.360625    -3.054729 -0.433625   2.022034     3.243118
# 775  2.639091  1.327003    -3.518562  0.127474   2.173234     2.061027
#
#        Expend  Grad.Rate  cluster                                   name
# 16   2.251520   2.020124        3                        Amherst College
# 60   2.064684   1.786312        3                        Bowdoin College
# 70   2.063345   1.844765        3                       Brown University
# 144  4.013746   1.961671        3                    Columbia University
# 158  3.818686   1.903218        3                      Dartmouth College
# 174  3.357237   1.844765        3                        Duke University
# 191  3.596472   1.786312        3                       Emory University
# 221  1.909401   1.727859        3                  Georgetown University
# 250  5.272069   2.020124        3                     Harvard University
# 251  2.279249   2.020124        3                    Harvey Mudd College
# 284  8.908201   1.435595        3               Johns Hopkins University
# 354  4.568708   1.669406        3  Massachusetts Institute of Technology
# 424  3.200234   1.552501        3                Northwestern University
# 459  3.570273   1.961671        3                   Princeton University
# 609  5.202268   1.435595        3                  University of Chicago
# 663  3.081669   1.610954        3             University of Pennsylvania
# 720  6.141612   1.377142        3                 Wake Forest University
# 728  6.894311   1.435595        3                  Washington University
# 733  2.248651   1.494048        3                      Wellesley College
# 763  2.364348   1.961671        3                       Williams College
# 775  5.877708   1.961671        3                        Yale University
